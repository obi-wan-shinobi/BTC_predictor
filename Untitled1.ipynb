# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams

rcParams['figure.figsize'] = 20,10

# %%
df = pd.read_csv('BTC-USD.csv')
df.dropna(inplace = True)

# %%
df.head()
# Out:
#          Date     Open     High      Low    Close  Adj Close  Volume
# 0  2010-07-17  0.04951  0.04951  0.04951  0.04951    0.04951       0
# 1  2010-07-18  0.04951  0.08585  0.05941  0.08584    0.08584       5
# 2  2010-07-19  0.08584  0.09307  0.07723  0.08080    0.08080      49
# 3  2010-07-20  0.08080  0.08181  0.07426  0.07474    0.07474      20
# 4  2010-07-21  0.07474  0.07921  0.06634  0.07921    0.07921      42

# %%
df.drop(['Open','High','Low','Adj Close','Volume'], axis = 1, inplace = True)

# %%
df.Date = pd.to_datetime(df.Date, format = '%Y-%m-%d')

# %%
df.set_index(df.Date, inplace = True)
data = df.sort_index(ascending = True, axis = 0)

# %%
Dates = df.Date

# %%
df.drop('Date', axis = 1, inplace = True)

# %%
y = df.Close[1800:]
x = Dates[1800:]

# %%
plt.plot(x,y)

# %%
df.shape
# Out:
# (3354, 1)

# %%
df = df[1800:]
Dates = Dates[1800:]

# %%
Close = df.Close.values

# %%
df.head()
# Out:
#                  Close
# Date
# 2015-06-21  244.100006
# 2015-06-22  247.460007
# 2015-06-23  243.759995
# 2015-06-24  240.559998
# 2015-06-25  242.559998

# %%
Close.shape
# Out:
# (1554,)

# %%
y_train = Close[:1000]
y_test = Close[1000:]

# %%
X_train, x_test = [],[]

# %%
for i in range(60,len(y_train)+60):
    X_train.append(Close[i-60:i])

# %%
X_train = np.array(X_train)

# %%
X_train = X_train.reshape(len(X_train), len(X_train[0]),1)

# %%
X_train.shape
# Out:
# (1000, 60, 1)

# %%
y_train = y_train.reshape(len(y_train),1)

# %%
y_train.shape
# Out:
# (1000, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers.recurrent import LSTM

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
model.add(LSTM(units=50))
model.add(Dense(1))
# Out:
# W0922 15:33:04.732154  6876 deprecation_wrapper.py:119] From c:\users\shinigami shrek\appdata\local\programs\python\python36\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0922 15:33:04.740149  6876 deprecation_wrapper.py:119] From c:\users\shinigami shrek\appdata\local\programs\python\python36\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
model.compile(optimizer = 'adam', loss='mean_squared_error', metrics = ['accuracy'])
# Out:
# W0922 15:33:52.189950  6876 deprecation_wrapper.py:119] From c:\users\shinigami shrek\appdata\local\programs\python\python36\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(X_train,y_train,
          epochs = 5,
          verbose = 1)
# Out:
# W0922 15:34:39.875669  6876 deprecation.py:323] From c:\users\shinigami shrek\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0922 15:34:41.179671  6876 deprecation_wrapper.py:119] From c:\users\shinigami shrek\appdata\local\programs\python\python36\lib\site-packages\keras\backend\tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0922 15:34:41.311673  6876 deprecation_wrapper.py:119] From c:\users\shinigami shrek\appdata\local\programs\python\python36\lib\site-packages\keras\backend\tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Epoch 1/1
# 1000/1000 [==============================] - 14s 14ms/step - loss: 21102484.3680 - acc: 0.0000e+00
