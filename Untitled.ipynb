# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
rcParams['figure.figsize'] = 20,10

# %%
df = pd.read_csv('BTC-USD.csv')

# %%
df.head()
# Out:
#          Date     Open     High      Low    Close  Adj Close  Volume
# 0  2010-07-17  0.04951  0.04951  0.04951  0.04951    0.04951       0
# 1  2010-07-18  0.04951  0.08585  0.05941  0.08584    0.08584       5
# 2  2010-07-19  0.08584  0.09307  0.07723  0.08080    0.08080      49
# 3  2010-07-20  0.08080  0.08181  0.07426  0.07474    0.07474      20
# 4  2010-07-21  0.07474  0.07921  0.06634  0.07921    0.07921      42

# %%
df.Date = pd.to_datetime(df.Date, format = '%Y-%m-%d')

# %%
x = df.Close
y = df.Date

# %%
plt.plot(y,x)

# %%
df = df[2500:]

# %%
len(df)
# Out:
# 854

# %%
df.head()
# Out:
#            Date         Open         High          Low        Close  \
# 2500 2017-05-21  2040.180054  2094.939941  1980.069946  2044.189941
# 2501 2017-05-22  2044.189941  2264.760010  1998.609985  2124.409912
# 2502 2017-05-23  2124.409912  2286.300049  2110.780029  2272.580078
# 2503 2017-05-24  2272.580078  2496.979980  2263.290039  2445.280029
# 2504 2017-05-25  2445.280029  2781.760010  2210.479980  2307.219971
#
#         Adj Close     Volume
# 2500  2044.189941  161036810
# 2501  2124.409912  373482496
# 2502  2272.580078  251969081
# 2503  2445.280029  353734030
# 2504  2307.219971  622139030

# %%
x = df.Date
y = df.Close

# %%
plt.plot(x,y)
